# %% [markdown]
# # Download Monthly EWS

# %% [markdown]
# ## From January 2000 to December 2009

# %%
from urllib.parse import urljoin
import itertools
import os
import requests

# make diretcory to save csv files
dir_path = '../data/1_EWS_raw'
os.makedirs(dir_path, exist_ok=True)

# Base URL
base_url_from_200001_to_200912 = 'https://www5.cao.go.jp/keizai3/kako_csv/kako2_watcher.html'

# list of year and month
hyy_dic = {'2000':'h12', '2001':'h13', '2002':'h14', '2003':'h15', 
           '2004':'h16', '2005':'h17', '2006':'h18', '2007':'h19',
           '2008':'h20', '2009':'h21'}
mm_list = ['01', '02', '03', '04', '05', '06', '07', '08', '09', '10', '11', '12']

def DL_csv(base_url, key, val, mm, target):
    csv_url = urljoin(base_url, f'{val}{mm}_{target}.csv')
    csv_filename = f'{key}{mm}_{target}.csv'
    file_path = os.path.join(dir_path, csv_filename)

    # Download the CSV file
    csv_res = requests.get(csv_url)
    with open(file_path, 'wb') as f:
        f.write(csv_res.content)

    print(f"Download completed: {csv_filename}")
    
for (hyy_key, hyy_val), mm in itertools.product(hyy_dic.items(), mm_list):
    DL_csv(base_url_from_200001_to_200912, hyy_key, hyy_val, mm, 'watcher4') # current
    DL_csv(base_url_from_200001_to_200912, hyy_key, hyy_val, mm, 'watcher5') # future
# Out:
# Download completed: 200001_watcher4.csv
# Download completed: 200001_watcher5.csv
# Download completed: 200002_watcher4.csv
# Download completed: 200002_watcher5.csv
# Download completed: 200003_watcher4.csv
# Download completed: 200003_watcher5.csv
# Download completed: 200004_watcher4.csv
# Download completed: 200004_watcher5.csv
# Download completed: 200005_watcher4.csv
# Download completed: 200005_watcher5.csv
# Download completed: 200006_watcher4.csv
# Download completed: 200006_watcher5.csv
# Download completed: 200007_watcher4.csv
# Download completed: 200007_watcher5.csv
# Download completed: 200008_watcher4.csv
# Download completed: 200008_watcher5.csv
# Download completed: 200009_watcher4.csv
# Download completed: 200009_watcher5.csv
# Download completed: 200010_watcher4.csv
# Download completed: 200010_watcher5.csv
# Download completed: 200011_watcher4.csv
# Download completed: 200011_watcher5.csv
# Download completed: 200012_watcher4.csv
# Download completed: 200012_watcher5.csv
# Download completed: 200101_watcher4.csv
# Download completed: 200101_watcher5.csv
# Download completed: 200102_watcher4.csv
# Download completed: 200102_watcher5.csv
# Download completed: 200103_watcher4.csv
# Download completed: 200103_watcher5.csv
# Download completed: 200104_watcher4.csv
# Download completed: 200104_watcher5.csv
# Download completed: 200105_watcher4.csv
# Download completed: 200105_watcher5.csv
# Download completed: 200106_watcher4.csv
# Download completed: 200106_watcher5.csv
# Download completed: 200107_watcher4.csv
# Download completed: 200107_watcher5.csv
# Download completed: 200108_watcher4.csv
# Download completed: 200108_watcher5.csv
# Download completed: 200109_watcher4.csv
# Download completed: 200109_watcher5.csv
# Download completed: 200110_watcher4.csv
# Download completed: 200110_watcher5.csv
# Download completed: 200111_watcher4.csv
# Download completed: 200111_watcher5.csv
# Download completed: 200112_watcher4.csv
# Download completed: 200112_watcher5.csv
# Download completed: 200201_watcher4.csv
# Download completed: 200201_watcher5.csv
# Download completed: 200202_watcher4.csv
# Download completed: 200202_watcher5.csv
# Download completed: 200203_watcher4.csv
# Download completed: 200203_watcher5.csv
# Download completed: 200204_watcher4.csv
# Download completed: 200204_watcher5.csv
# Download completed: 200205_watcher4.csv
# Download completed: 200205_watcher5.csv
# Download completed: 200206_watcher4.csv
# Download completed: 200206_watcher5.csv
# Download completed: 200207_watcher4.csv
# Download completed: 200207_watcher5.csv
# Download completed: 200208_watcher4.csv
# Download completed: 200208_watcher5.csv
# Download completed: 200209_watcher4.csv
# Download completed: 200209_watcher5.csv
# Download completed: 200210_watcher4.csv
# Download completed: 200210_watcher5.csv
# Download completed: 200211_watcher4.csv
# Download completed: 200211_watcher5.csv
# Download completed: 200212_watcher4.csv
# Download completed: 200212_watcher5.csv
# Download completed: 200301_watcher4.csv
# Download completed: 200301_watcher5.csv
# Download completed: 200302_watcher4.csv
# Download completed: 200302_watcher5.csv
# Download completed: 200303_watcher4.csv
# Download completed: 200303_watcher5.csv
# Download completed: 200304_watcher4.csv
# Download completed: 200304_watcher5.csv
# Download completed: 200305_watcher4.csv
# Download completed: 200305_watcher5.csv
# Download completed: 200306_watcher4.csv
# Download completed: 200306_watcher5.csv
# Download completed: 200307_watcher4.csv
# Download completed: 200307_watcher5.csv
# Download completed: 200308_watcher4.csv
# Download completed: 200308_watcher5.csv
# Download completed: 200309_watcher4.csv
# Download completed: 200309_watcher5.csv
# Download completed: 200310_watcher4.csv
# Download completed: 200310_watcher5.csv
# Download completed: 200311_watcher4.csv
# Download completed: 200311_watcher5.csv
# Download completed: 200312_watcher4.csv
# Download completed: 200312_watcher5.csv
# Download completed: 200401_watcher4.csv
# Download completed: 200401_watcher5.csv
# Download completed: 200402_watcher4.csv
# Download completed: 200402_watcher5.csv
# Download completed: 200403_watcher4.csv
# Download completed: 200403_watcher5.csv
# Download completed: 200404_watcher4.csv
# Download completed: 200404_watcher5.csv
# Download completed: 200405_watcher4.csv
# Download completed: 200405_watcher5.csv
# Download completed: 200406_watcher4.csv
# Download completed: 200406_watcher5.csv
# Download completed: 200407_watcher4.csv
# Download completed: 200407_watcher5.csv
# Download completed: 200408_watcher4.csv
# Download completed: 200408_watcher5.csv
# Download completed: 200409_watcher4.csv
# Download completed: 200409_watcher5.csv
# Download completed: 200410_watcher4.csv
# Download completed: 200410_watcher5.csv
# Download completed: 200411_watcher4.csv
# Download completed: 200411_watcher5.csv
# Download completed: 200412_watcher4.csv
# Download completed: 200412_watcher5.csv
# Download completed: 200501_watcher4.csv
# Download completed: 200501_watcher5.csv
# Download completed: 200502_watcher4.csv
# Download completed: 200502_watcher5.csv
# Download completed: 200503_watcher4.csv
# Download completed: 200503_watcher5.csv
# Download completed: 200504_watcher4.csv
# Download completed: 200504_watcher5.csv
# Download completed: 200505_watcher4.csv
# Download completed: 200505_watcher5.csv
# Download completed: 200506_watcher4.csv
# Download completed: 200506_watcher5.csv
# Download completed: 200507_watcher4.csv
# Download completed: 200507_watcher5.csv
# Download completed: 200508_watcher4.csv
# Download completed: 200508_watcher5.csv
# Download completed: 200509_watcher4.csv
# Download completed: 200509_watcher5.csv
# Download completed: 200510_watcher4.csv
# Download completed: 200510_watcher5.csv
# Download completed: 200511_watcher4.csv
# Download completed: 200511_watcher5.csv
# Download completed: 200512_watcher4.csv
# Download completed: 200512_watcher5.csv
# Download completed: 200601_watcher4.csv
# Download completed: 200601_watcher5.csv
# Download completed: 200602_watcher4.csv
# Download completed: 200602_watcher5.csv
# Download completed: 200603_watcher4.csv
# Download completed: 200603_watcher5.csv
# Download completed: 200604_watcher4.csv
# Download completed: 200604_watcher5.csv
# Download completed: 200605_watcher4.csv
# Download completed: 200605_watcher5.csv
# Download completed: 200606_watcher4.csv
# Download completed: 200606_watcher5.csv
# Download completed: 200607_watcher4.csv
# Download completed: 200607_watcher5.csv
# Download completed: 200608_watcher4.csv
# Download completed: 200608_watcher5.csv
# Download completed: 200609_watcher4.csv
# Download completed: 200609_watcher5.csv
# Download completed: 200610_watcher4.csv
# Download completed: 200610_watcher5.csv
# Download completed: 200611_watcher4.csv
# Download completed: 200611_watcher5.csv
# Download completed: 200612_watcher4.csv
# Download completed: 200612_watcher5.csv
# Download completed: 200701_watcher4.csv
# Download completed: 200701_watcher5.csv
# Download completed: 200702_watcher4.csv
# Download completed: 200702_watcher5.csv
# Download completed: 200703_watcher4.csv
# Download completed: 200703_watcher5.csv
# Download completed: 200704_watcher4.csv
# Download completed: 200704_watcher5.csv
# Download completed: 200705_watcher4.csv
# Download completed: 200705_watcher5.csv
# Download completed: 200706_watcher4.csv
# Download completed: 200706_watcher5.csv
# Download completed: 200707_watcher4.csv
# Download completed: 200707_watcher5.csv
# Download completed: 200708_watcher4.csv
# Download completed: 200708_watcher5.csv
# Download completed: 200709_watcher4.csv
# Download completed: 200709_watcher5.csv
# Download completed: 200710_watcher4.csv
# Download completed: 200710_watcher5.csv
# Download completed: 200711_watcher4.csv
# Download completed: 200711_watcher5.csv
# Download completed: 200712_watcher4.csv
# Download completed: 200712_watcher5.csv
# Download completed: 200801_watcher4.csv
# Download completed: 200801_watcher5.csv
# Download completed: 200802_watcher4.csv
# Download completed: 200802_watcher5.csv
# Download completed: 200803_watcher4.csv
# Download completed: 200803_watcher5.csv
# Download completed: 200804_watcher4.csv
# Download completed: 200804_watcher5.csv
# Download completed: 200805_watcher4.csv
# Download completed: 200805_watcher5.csv
# Download completed: 200806_watcher4.csv
# Download completed: 200806_watcher5.csv
# Download completed: 200807_watcher4.csv
# Download completed: 200807_watcher5.csv
# Download completed: 200808_watcher4.csv
# Download completed: 200808_watcher5.csv
# Download completed: 200809_watcher4.csv
# Download completed: 200809_watcher5.csv
# Download completed: 200810_watcher4.csv
# Download completed: 200810_watcher5.csv
# Download completed: 200811_watcher4.csv
# Download completed: 200811_watcher5.csv
# Download completed: 200812_watcher4.csv
# Download completed: 200812_watcher5.csv
# Download completed: 200901_watcher4.csv
# Download completed: 200901_watcher5.csv
# Download completed: 200902_watcher4.csv
# Download completed: 200902_watcher5.csv
# Download completed: 200903_watcher4.csv
# Download completed: 200903_watcher5.csv
# Download completed: 200904_watcher4.csv
# Download completed: 200904_watcher5.csv
# Download completed: 200905_watcher4.csv
# Download completed: 200905_watcher5.csv
# Download completed: 200906_watcher4.csv
# Download completed: 200906_watcher5.csv
# Download completed: 200907_watcher4.csv
# Download completed: 200907_watcher5.csv
# Download completed: 200908_watcher4.csv
# Download completed: 200908_watcher5.csv
# Download completed: 200909_watcher4.csv
# Download completed: 200909_watcher5.csv
# Download completed: 200910_watcher4.csv
# Download completed: 200910_watcher5.csv
# Download completed: 200911_watcher4.csv
# Download completed: 200911_watcher5.csv
# Download completed: 200912_watcher4.csv
# Download completed: 200912_watcher5.csv

# %% [markdown]
# ## From January 2010 onward

# %%
from bs4 import BeautifulSoup as bs
import re

# Base URL
base_url_from_201001_to_201912 = 'https://www5.cao.go.jp/keizai3/kako_watcher.html'
base_url_from_202001 = 'https://www5.cao.go.jp/keizai3/watcher_index.html'

# function to get monthly links
def get_monthly_links(base_url):
    # get monthly page bullet links
    res = requests.get(base_url)
    soup = bs(res.content, 'html.parser')
    monthly_bullet_links = soup.find_all('a', class_=re.compile('bulletLink'))
    
    # extract monthly page links
    monthly_links = []
    for monthly_bullet_link in monthly_bullet_links:
        monthly_link = monthly_bullet_link.get('href')
        if monthly_link.startswith('20'):
            if (int(monthly_link[:4])<=2009) | (monthly_link[:7]=='2010/01'): # skip data before 2009 here
                continue
            monthly_links.append(monthly_link)
    return sorted(monthly_links)

monthly_links_from_201001_to_201912 = get_monthly_links(base_url_from_201001_to_201912)
monthly_links_from_202001 = get_monthly_links(base_url_from_202001)
monthly_links = monthly_links_from_201001_to_201912 + monthly_links_from_202001

# create dictionary (key:months, value:url)
key_list = [str(int(m[:7].replace('/', ''))-1) for m in monthly_links]
key_list = [
    key[:2] + str(int(key[2:4])-1) + '12' + key[6:] if key[4:6] == '00' else key
    for key in key_list
] # For example, '201800' is modified as '201712'
url_dict = dict(zip(key_list, monthly_links))

# function to download CSVs
def download_csv(key, url, csv_link_tag):
    if csv_link_tag:
        csv_url = urljoin(url, csv_link_tag['href'])
        csv_filename = f'{key}_{os.path.basename(csv_url)}'
        file_path = os.path.join(dir_path, csv_filename)

        # Download the CSV file
        csv_res = requests.get(csv_url)
        with open(file_path, 'wb') as f:
            f.write(csv_res.content)

        print(f"Download completed: {csv_filename}")
    else:
        print(f"{key}: CSV link not found.")

# Iterate through the dictionary and download CSV files from each URL
for key, url in url_dict.items():
    res = requests.get('https://www5.cao.go.jp/keizai3/'+url)
    res.encoding = 'utf-8'
    soup = bs(res.text, 'html.parser')

    # Extract a specific CSV file links
    current_csv_link_tag = soup.find('a', href='watcher4.csv')
    future_csv_link_tag = soup.find('a', href='watcher5.csv')

    # download csv files
    download_csv(key, 'https://www5.cao.go.jp/keizai3/'+url, current_csv_link_tag)
    download_csv(key, 'https://www5.cao.go.jp/keizai3/'+url, future_csv_link_tag)
# Out:
# Download completed: 201001_watcher4.csv
# Download completed: 201001_watcher5.csv
# Download completed: 201002_watcher4.csv
# Download completed: 201002_watcher5.csv
# Download completed: 201003_watcher4.csv
# Download completed: 201003_watcher5.csv
# Download completed: 201004_watcher4.csv
# Download completed: 201004_watcher5.csv
# Download completed: 201005_watcher4.csv
# Download completed: 201005_watcher5.csv
# Download completed: 201006_watcher4.csv
# Download completed: 201006_watcher5.csv
# Download completed: 201007_watcher4.csv
# Download completed: 202107_watcher4.csv
# Download completed: 202107_watcher5.csv
# Download completed: 202108_watcher4.csv
# Download completed: 202108_watcher5.csv
# Download completed: 202109_watcher4.csv
# Download completed: 202109_watcher5.csv
# Download completed: 202110_watcher4.csv
# Download completed: 202110_watcher5.csv
# Download completed: 202111_watcher4.csv
# Download completed: 202111_watcher5.csv
# Download completed: 202112_watcher4.csv
# Download completed: 202112_watcher5.csv
# Download completed: 202201_watcher4.csv
# Download completed: 202201_watcher5.csv
# Download completed: 202202_watcher4.csv
# Download completed: 202202_watcher5.csv
# Download completed: 202203_watcher4.csv
# Download completed: 202203_watcher5.csv
# Download completed: 202204_watcher4.csv
# Download completed: 202204_watcher5.csv
# Download completed: 202205_watcher4.csv
# Download completed: 202205_watcher5.csv
# Download completed: 202206_watcher4.csv
# Download completed: 202206_watcher5.csv
# Download completed: 202207_watcher4.csv
# Download completed: 202207_watcher5.csv
# Download completed: 202208_watcher4.csv
# Download completed: 202208_watcher5.csv
# Download completed: 202209_watcher4.csv
# Download completed: 202209_watcher5.csv
# Download completed: 202210_watcher4.csv
# Download completed: 202210_watcher5.csv
# Download completed: 202211_watcher4.csv
# Download completed: 202211_watcher5.csv
# Download completed: 202212_watcher4.csv
# Download completed: 202212_watcher5.csv
# Download completed: 202301_watcher4.csv
# Download completed: 202301_watcher5.csv
# Download completed: 202302_watcher4.csv
# Download completed: 202302_watcher5.csv
# Download completed: 202303_watcher4.csv
# Download completed: 202303_watcher5.csv
# Download completed: 202304_watcher4.csv
# Download completed: 202304_watcher5.csv
# Download completed: 202305_watcher4.csv
# Download completed: 202305_watcher5.csv
# Download completed: 202306_watcher4.csv
# Download completed: 202306_watcher5.csv
# Download completed: 202307_watcher4.csv
# Download completed: 202307_watcher5.csv
# Download completed: 202308_watcher4.csv
# Download completed: 202308_watcher5.csv
# Download completed: 202309_watcher4.csv
# Download completed: 202309_watcher5.csv
# Download completed: 202310_watcher4.csv
# Download completed: 202310_watcher5.csv
# Download completed: 202311_watcher4.csv
# Download completed: 202311_watcher5.csv
# Download completed: 202312_watcher4.csv
# Download completed: 202312_watcher5.csv
# Download completed: 202401_watcher4.csv
# Download completed: 202401_watcher5.csv
# Download completed: 202402_watcher4.csv
# Download completed: 202402_watcher5.csv
# Download completed: 202403_watcher4.csv
# Download completed: 202403_watcher5.csv
# Download completed: 202404_watcher4.csv
# Download completed: 202404_watcher5.csv
# Download completed: 202405_watcher4.csv
# Download completed: 202405_watcher5.csv
# Download completed: 202406_watcher4.csv
# Download completed: 202406_watcher5.csv
# Download completed: 202407_watcher4.csv
# Download completed: 202407_watcher5.csv
# Download completed: 202408_watcher4.csv
# Download completed: 202408_watcher5.csv
# Download completed: 202409_watcher4.csv
# Download completed: 202409_watcher5.csv
# Download completed: 202410_watcher4.csv
# Download completed: 202410_watcher5.csv
# Download completed: 202411_watcher4.csv
# Download completed: 202411_watcher5.csv
# Download completed: 202412_watcher4.csv
# Download completed: 202412_watcher5.csv
# Download completed: 202501_watcher4.csv
# Download completed: 202501_watcher5.csv
# Download completed: 202502_watcher4.csv
# Download completed: 202502_watcher5.csv
